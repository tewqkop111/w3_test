# %%
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:y=5*x**2+20*x+10
def func(x): return 5*x**2+20*x+10

# 目標函數一階導數:dy/dx=10*x+20
def dfunc(x): return 10*x+20

def GD(x_start, df, epochs, lr):
    xs = np.zeros(epochs+1)    
    x = x_start    
    xs[0] = x    
    for i in range(epochs):         
        dx = df(x)        
        # v表示x要改變的幅度        
        v =  - dx * lr        
        x += v        
        xs[i+1] = x    
    return xs

# Main
# 起始權重
x_start = 4
# 執行週期數
epochs = 30
# 學習率   
lr = 0.2
# 梯度下降法 
x = GD(x_start, dfunc, epochs, lr) 
print (x)

color = 'r' 
from numpy import arange
t = arange(-10, 6, 0.01)
plt.plot(t, func(t), c='b')
plt.plot(x, func(x), c=color, label='lr={}'.format(lr))    
plt.scatter(x, func(x), c=color, )    
plt.legend()

plt.show()
# Out:
# [ 4. -8.  4. -8.  4. -8.  4. -8.  4. -8.  4. -8.  4. -8.  4. -8.  4. -8.
#   4. -8.  4. -8.  4. -8.  4. -8.  4. -8.  4. -8.  4.]

# %%
import numpy as np
import matplotlib.pyplot as plt

# 目標函數:x=500*y-2*y**2
def func(y): return 500*y-2*y**2

# 目標函數一階導數:dx/dy= 500-4*y
def dfunc(y): return 500-4*y

def GD(y_start, df, epochs, lr):
    ys = np.zeros(epochs+1)    
    y = y_start    
    ys[0] = y    
    for i in range(epochs):         
        dy = df(y)        
        # v表示x要改變的幅度        
        v =  - dy * lr        
        y -= v        
        ys[i+1] = y    
    return ys

# Main
# 起始權重
y_start = 131
# 執行週期數
epochs = 50
# 學習率   
lr = 0.4

y = GD(y_start, dfunc, epochs, lr) 
print (y)

color = 'r' 
from numpy import arange
t = arange(118, 132, 0.01)
plt.plot(t, func(t), c='b')
plt.plot(y, func(y), c=color, label='lr={}'.format(lr))    
plt.scatter(y, func(y), c=color, )    
plt.legend()

plt.show()
# Out:
# [131.         121.4        127.16       123.704      125.7776
#  124.53344    125.279936   124.8320384  125.10077696 124.93953382
#  125.03627971 124.97823218 125.01306069 124.99216358 125.00470185
#  124.99717889 125.00169267 124.9989844  125.00060936 124.99963438
#  125.00021937 124.99986838 125.00007897 124.99995262 125.00002843
#  124.99998294 125.00001023 124.99999386 125.00000368 124.99999779
#  125.00000133 124.9999992  125.00000048 124.99999971 125.00000017
#  124.9999999  125.00000006 124.99999996 125.00000002 124.99999999
#  125.00000001 125.         125.         125.         125.
#  125.         125.         125.         125.         125.
#  125.        ]
